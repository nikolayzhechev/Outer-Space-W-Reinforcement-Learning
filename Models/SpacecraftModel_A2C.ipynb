# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

import gymnasium as gym
from gymnasium import spaces

from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import PPO, A2C, DQN
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# ### A2C Hyperparameters
#
# | **Hyperparameter**             | **Value**  | **Reasoning** |
# |--------------------------------|-----------------------|---------------|
# | **Discount Factor (γ)**        | `0.99`                | Ensures long-term reward optimization, critical for docking. |
# | **Learning Rate (α)**          | `3e-4`                | Balanced learning speed; lower values improve stability. |
# | **Number of Environments**     | `8-16`                | Helps stabilize updates via multiple experiences. |
# | **Entropy Coefficient (β)**    | `0.01 - 0.05`         | Encourages exploration but keeps it controlled. |
# | **Value Function Coefficient (c1)** | `0.5`          | Ensures a good balance between policy and value updates. |
# | **Gradient Clip**              | `0.5`                 | Prevents exploding gradients, improving stability. |
# | **Batch Size**                 | `128 - 256`           | Larger batches improve stability for continuous control. |
# | **Max Episode Length**         | `500 - 1000` steps    | Allows enough time for docking maneuvers. |
# | **Activation Function**        | `ReLU` (or `Tanh`)    | `Tanh` can help with smoother control in continuous actions. |
# | **Policy Network Architecture** | `2-3 layers, 256-512 neurons each` | Sufficient capacity for learning complex docking strategies. |
# | **Value Network Architecture** | `Same as policy network` | A2C uses separate policy and value networks. |
# | **Optimizer**                  | `Adam`                | Standard and stable for RL applications. |
# | **Frame Skip** (if using vision) | `1-4`               | Helps reduce training complexity in high-frame-rate environments. |

# %%
# Import environment creator function
from Environment_Creator import env_creator, Environments_enum
# Instantiate one of the custom environments
config = None

# %%
# Fetch environment
def make_navigation_env():
    return env_creator(Environments_enum.Navigation.value)
    
# Register the custom environment with Gym
gym.register(
    id="SpacecraftNavigation_v2",
    entry_point=make_navigation_env
)
# Verify environment registry
gym.pprint_registry()

# Make our environment
gym_env = gym.make("SpacecraftNavigation_v2")

# Instantiate the env
vec_env = make_vec_env("SpacecraftNavigation_v2", n_envs=8)
# Out:
# ===== classic_control =====
# Acrobot-v1                  CartPole-v0                 CartPole-v1
# MountainCar-v0              MountainCarContinuous-v0    Pendulum-v1
# ===== phys2d =====
# phys2d/CartPole-v0          phys2d/CartPole-v1          phys2d/Pendulum-v0
# ===== box2d =====
# BipedalWalker-v3            BipedalWalkerHardcore-v3    CarRacing-v2
# LunarLander-v2              LunarLanderContinuous-v2
# ===== toy_text =====
# Blackjack-v1                CliffWalking-v0             FrozenLake-v1
# FrozenLake8x8-v1            Taxi-v3
# ===== tabular =====
# tabular/Blackjack-v0        tabular/CliffWalking-v0
# ===== mujoco =====
# Ant-v2                      Ant-v3                      Ant-v4
# HalfCheetah-v2              HalfCheetah-v3              HalfCheetah-v4
# Hopper-v2                   Hopper-v3                   Hopper-v4
# Humanoid-v2                 Humanoid-v3                 Humanoid-v4
# HumanoidStandup-v2          HumanoidStandup-v4          InvertedDoublePendulum-v2
# InvertedDoublePendulum-v4   InvertedPendulum-v2         InvertedPendulum-v4
# Pusher-v2                   Pusher-v4                   Reacher-v2
# Reacher-v4                  Swimmer-v2                  Swimmer-v3
# Swimmer-v4                  Walker2d-v2                 Walker2d-v3
# Walker2d-v4
# ===== None =====
# GymV21Environment-v0        GymV26Environment-v0        SpacecraftDockingEnv-v0
# SpacecraftDocking_v2        SpacecraftInterplanetary_v2 SpacecraftNavigation_v2
# C:\Users\zhech\AppData\Local\Programs\Python\Python310\lib\site-packages\gymnasium\envs\registration.py:694: UserWarning: WARN: Overriding environment SpacecraftNavigation_v2 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
model = A2C(
    policy='MlpPolicy',  # Use MLP Policy for a standard neural network (can change to custom policy if needed)
    env=vec_env,  # Your environment
    learning_rate=3e-4,  # From the table
    n_steps=5,  # Default value, you can increase this to match batch size preferences
    gamma=0.99,  # From the table
    gae_lambda=1.0,  # From the table, helps with Generalized Advantage Estimation
    ent_coef=0.01,  # From the table, controls entropy for exploration
    vf_coef=0.5,  # From the table, balance between policy and value function
    max_grad_norm=0.5,  # From the table, limits gradient explosion
    rms_prop_eps=1e-5,  # Default value for RMSProp, stability for gradient updates
    use_rms_prop=True,  # Using RMSProp for stable optimization
    use_sde=False,  # You can enable for stochastic networks (usually optional)
    sde_sample_freq=-1,  # Only relevant if use_sde=True
    normalize_advantage=False,  # Keep advantage normalization as False unless needed
    stats_window_size=100,  # The size of the window for stats tracking
    tensorboard_log=None,  # Optional, specify a path if you want TensorBoard logs
    policy_kwargs=None,  # For additional custom policy configuration (e.g., network architecture)
    verbose=1,  # Verbosity level, 1 will print some details during training
    seed=None,  # Set a seed for reproducibility if desired
    device='auto',  # Automatically selects the device (CPU or GPU)
    _init_setup_model=True,  # Initialize model setup if you haven't done that elsewhere
)
model.learn(1e6)
# Out:
# Using cpu device
# C:\Users\zhech\AppData\Local\Programs\Python\Python310\lib\site-packages\gymnasium\utils\passive_env_checker.py:135: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# C:\Users\zhech\AppData\Local\Programs\Python\Python310\lib\site-packages\gymnasium\utils\passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 92.9     |
# |    ep_rew_mean        | -91.8    |
# | time/                 |          |
# |    fps                | 2331     |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.71    |
# |    explained_variance | -0.00226 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 99       |
# |    policy_loss        | -4.52    |
# |    value_loss         | 18.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.1     |
# |    ep_rew_mean        | -90.6    |
# | time/                 |          |
# |    fps                | 2212     |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.65    |
# |    explained_variance | 0.191    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 199      |
# |    policy_loss        | -4.58    |
# |    value_loss         | 12.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84.1     |
# |    ep_rew_mean        | -78      |
# | time/                 |          |
# |    fps                | 2221     |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.66    |
# |    explained_variance | 5.1e-05  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 299      |
# |    policy_loss        | -2.27    |
# |    value_loss         | 46.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 78.5     |
# |    ep_rew_mean        | -69.3    |
# | time/                 |          |
# |    fps                | 2263     |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.66    |
# |    explained_variance | 0.34     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 399      |
# |    policy_loss        | -1.13    |
# |    value_loss         | 4.5      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 78.9     |
# |    ep_rew_mean        | -68.8    |
# | time/                 |          |
# |    fps                | 2278     |
# |    iterations         | 500      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.375    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 499      |
# |    policy_loss        | -3.68    |
# |    value_loss         | 10.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77.4     |
# |    ep_rew_mean        | -66.6    |
# | time/                 |          |
# |    fps                | 2284     |
# |    iterations         | 600      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.53    |
# |    explained_variance | 0.0319   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 599      |
# |    policy_loss        | -1.04    |
# |    value_loss         | 50.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 72.7     |
# |    ep_rew_mean        | -57.6    |
# | time/                 |          |
# |    fps                | 2279     |
# |    iterations         | 700      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | 0.773    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.375   |
# |    value_loss         | 0.797    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 63.3     |
# |    ep_rew_mean        | -45.6    |
# | time/                 |          |
# |    fps                | 2283     |
# |    iterations         | 800      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.5     |
# |    explained_variance | 0.293    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 799      |
# |    policy_loss        | -2.4     |
# |    value_loss         | 22.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 57       |
# |    ep_rew_mean        | -38.5    |
# | time/                 |          |
# |    fps                | 2296     |
# |    iterations         | 900      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -1.46    |
# |    explained_variance | -0.0565  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 899      |
# |    policy_loss        | 4.63     |
# |    value_loss         | 107      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 60.8     |
# |    ep_rew_mean        | -39.8    |
# | time/                 |          |
# |    fps                | 2296     |
# |    iterations         | 1000     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -1.47    |
# |    explained_variance | 0.486    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 999      |
# |    policy_loss        | -2.11    |
# |    value_loss         | 5.33     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47       |
# |    ep_rew_mean        | -24.7    |
# | time/                 |          |
# |    fps                | 2303     |
# |    iterations         | 1100     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -1.45    |
# |    explained_variance | 0.299    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1099     |
# |    policy_loss        | -1.55    |
# |    value_loss         | 24.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42.8     |
# |    ep_rew_mean        | -16.6    |
# | time/                 |          |
# |    fps                | 2331     |
# |    iterations         | 1200     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | 0.175    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1199     |
# |    policy_loss        | -1.43    |
# |    value_loss         | 36.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 33.6     |
# |    ep_rew_mean        | -7.8     |
# | time/                 |          |
# |    fps                | 2334     |
# |    iterations         | 1300     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | 0.0273   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1299     |
# |    policy_loss        | 2.22     |
# |    value_loss         | 120      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.5     |
# |    ep_rew_mean        | -5.86    |
# | time/                 |          |
# |    fps                | 2340     |
# |    iterations         | 1400     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.853    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1399     |
# |    policy_loss        | -2.98    |
# |    value_loss         | 9.05     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.3     |
# |    ep_rew_mean        | -0.422   |
# | time/                 |          |
# |    fps                | 2342     |
# |    iterations         | 1500     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -1.24    |
# |    explained_variance | 0.856    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1499     |
# |    policy_loss        | -1.44    |
# |    value_loss         | 8.46     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.6     |
# |    ep_rew_mean        | -1.66    |
# | time/                 |          |
# |    fps                | 2342     |
# |    iterations         | 1600     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.19     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1599     |
# |    policy_loss        | 3.82     |
# |    value_loss         | 118      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 19.9     |
# |    ep_rew_mean        | -0.524   |
# | time/                 |          |
# |    fps                | 2341     |
# |    iterations         | 1700     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -1.24    |
# |    explained_variance | 0.941    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1699     |
# |    policy_loss        | -2.29    |
# |    value_loss         | 5.91     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.5     |
# |    ep_rew_mean        | -0.741   |
# | time/                 |          |
# |    fps                | 2344     |
# |    iterations         | 1800     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -0.209   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1799     |
# |    policy_loss        | 1.24     |
# |    value_loss         | 38.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 19       |
# |    ep_rew_mean        | 1.27     |
# | time/                 |          |
# |    fps                | 2345     |
# |    iterations         | 1900     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -0.0218  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.654   |
# |    value_loss         | 15.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.1     |
# |    ep_rew_mean        | 4.43     |
# | time/                 |          |
# |    fps                | 2341     |
# |    iterations         | 2000     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | 0.968    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.37    |
# |    value_loss         | 1.77     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.4     |
# |    ep_rew_mean        | 6.32     |
# | time/                 |          |
# |    fps                | 2342     |
# |    iterations         | 2100     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -0.962   |
# |    explained_variance | 0.0246   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2099     |
# |    policy_loss        | -2.99    |
# |    value_loss         | 19       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.3     |
# |    ep_rew_mean        | 7.3      |
# | time/                 |          |
# |    fps                | 2359     |
# |    iterations         | 2200     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -0.917   |
# |    explained_variance | -0.369   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.23    |
# |    value_loss         | 1.29     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.1     |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 2358     |
# |    iterations         | 2300     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.961   |
# |    explained_variance | 0.216    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.107    |
# |    value_loss         | 0.147    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.2     |
# |    ep_rew_mean        | 5.84     |
# | time/                 |          |
# |    fps                | 2357     |
# |    iterations         | 2400     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.858   |
# |    explained_variance | -0.52    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.362    |
# |    value_loss         | 9.85     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.5     |
# |    ep_rew_mean        | 5.75     |
# | time/                 |          |
# |    fps                | 2357     |
# |    iterations         | 2500     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.917   |
# |    explained_variance | -0.0202  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.0873   |
# |    value_loss         | 0.228    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.3     |
# |    ep_rew_mean        | 9.18     |
# | time/                 |          |
# |    fps                | 2357     |
# |    iterations         | 2600     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -0.905   |
# |    explained_variance | 0.0128   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2599     |
# |    policy_loss        | -1.42    |
# |    value_loss         | 26.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.8     |
# |    ep_rew_mean        | 6.93     |
# | time/                 |          |
# |    fps                | 2365     |
# |    iterations         | 2700     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -0.901   |
# |    explained_variance | 0.0224   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2699     |
# |    policy_loss        | -1.62    |
# |    value_loss         | 19.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.7     |
# |    ep_rew_mean        | 9.54     |
# | time/                 |          |
# |    fps                | 2364     |
# |    iterations         | 2800     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -0.898   |
# |    explained_variance | -0.528   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.367   |
# |    value_loss         | 1.03     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24       |
# |    ep_rew_mean        | 9.92     |
# | time/                 |          |
# |    fps                | 2360     |
# |    iterations         | 2900     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -0.845   |
# |    explained_variance | -3.11    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.282    |
# |    value_loss         | 0.969    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.9     |
# |    ep_rew_mean        | 9.83     |
# | time/                 |          |
# |    fps                | 2361     |
# |    iterations         | 3000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -0.868   |
# |    explained_variance | 0.697    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.0192  |
# |    value_loss         | 0.043    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.1     |
# |    ep_rew_mean        | 8.9      |
# | time/                 |          |
# |    fps                | 2361     |
# |    iterations         | 3100     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -0.814   |
# |    explained_variance | 0.205    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.909   |
# |    value_loss         | 2.04     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.3     |
# |    ep_rew_mean        | 10.6     |
# | time/                 |          |
# |    fps                | 2358     |
# |    iterations         | 3200     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -0.788   |
# |    explained_variance | 0.373    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.0607  |
# |    value_loss         | 0.06     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.6     |
# |    ep_rew_mean        | 10.8     |
# | time/                 |          |
# |    fps                | 2357     |
# |    iterations         | 3300     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -0.836   |
# |    explained_variance | 0.0604   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.552   |
# |    value_loss         | 11       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.3     |
# |    ep_rew_mean        | 10.8     |
# | time/                 |          |
# |    fps                | 2356     |
# |    iterations         | 3400     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -0.639   |
# |    explained_variance | -0.0731  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.13     |
# |    value_loss         | 0.159    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.9     |
# |    ep_rew_mean        | 11.5     |
# | time/                 |          |
# |    fps                | 2355     |
# |    iterations         | 3500     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 140000   |
# | train/                |          |
# |    entropy_loss       | -0.77    |
# |    explained_variance | 0.786    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.0673  |
# |    value_loss         | 0.0338   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.2     |
# |    ep_rew_mean        | 10.6     |
# | time/                 |          |
# |    fps                | 2356     |
# |    iterations         | 3600     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -0.755   |
# |    explained_variance | 0.319    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.338   |
# |    value_loss         | 0.391    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.7     |
# |    ep_rew_mean        | 10.5     |
# | time/                 |          |
# |    fps                | 2355     |
# |    iterations         | 3700     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 148000   |
# | train/                |          |
# |    entropy_loss       | -0.754   |
# |    explained_variance | 0.0694   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3699     |
# |    policy_loss        | -1.08    |
# |    value_loss         | 5.73     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.4     |
# |    ep_rew_mean        | 11       |
# | time/                 |          |
# |    fps                | 2353     |
# |    iterations         | 3800     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 152000   |
# | train/                |          |
# |    entropy_loss       | -0.82    |
# |    explained_variance | 0.805    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.00514 |
# |    value_loss         | 0.0138   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.1     |
# |    ep_rew_mean        | 11.9     |
# | time/                 |          |
# |    fps                | 2353     |
# |    iterations         | 3900     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 156000   |
# | train/                |          |
# |    entropy_loss       | -0.73    |
# |    explained_variance | 0.0889   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.643   |
# |    value_loss         | 2.07     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.6     |
# |    ep_rew_mean        | 11.4     |
# | time/                 |          |
# |    fps                | 2359     |
# |    iterations         | 4000     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 160000   |
# | train/                |          |
# |    entropy_loss       | -0.727   |
# |    explained_variance | 0.767    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0254  |
# |    value_loss         | 0.0416   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.8     |
# |    ep_rew_mean        | 10.2     |
# | time/                 |          |
# |    fps                | 2358     |
# |    iterations         | 4100     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 164000   |
# | train/                |          |
# |    entropy_loss       | -0.648   |
# |    explained_variance | 0.474    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.0217  |
# |    value_loss         | 0.113    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.1     |
# |    ep_rew_mean        | 11.8     |
# | time/                 |          |
# |    fps                | 2360     |
# |    iterations         | 4200     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 168000   |
# | train/                |          |
# |    entropy_loss       | -0.643   |
# |    explained_variance | 0.728    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0185  |
# |    value_loss         | 0.0394   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.1     |
# |    ep_rew_mean        | 11.9     |
# | time/                 |          |
# |    fps                | 2362     |
# |    iterations         | 4300     |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 172000   |
# | train/                |          |
# |    entropy_loss       | -0.671   |
# |    explained_variance | 0.739    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.0291  |
# |    value_loss         | 0.0522   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.3     |
# |    ep_rew_mean        | 11.4     |
# | time/                 |          |
# |    fps                | 2362     |
# |    iterations         | 4400     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 176000   |
# | train/                |          |
# |    entropy_loss       | -0.608   |
# |    explained_variance | 0.774    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.00741  |
# |    value_loss         | 0.0142   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.5     |
# |    ep_rew_mean        | 11.4     |
# | time/                 |          |
# |    fps                | 2362     |
# |    iterations         | 4500     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 180000   |
# | train/                |          |
# |    entropy_loss       | -0.75    |
# |    explained_variance | 0.477    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.184   |
# |    value_loss         | 0.239    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.8     |
# |    ep_rew_mean        | 10.8     |
# | time/                 |          |
# |    fps                | 2362     |
# |    iterations         | 4600     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 184000   |
# | train/                |          |
# |    entropy_loss       | -0.595   |
# |    explained_variance | 0.911    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.0167  |
# |    value_loss         | 0.0104   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.1     |
# |    ep_rew_mean        | 10.8     |
# | time/                 |          |
# |    fps                | 2362     |
# |    iterations         | 4700     |
# |    time_elapsed       | 79       |
# |    total_timesteps    | 188000   |
# | train/                |          |
# |    entropy_loss       | -0.59    |
# |    explained_variance | 0.802    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.0704  |
# |    value_loss         | 0.0269   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.8     |
# |    ep_rew_mean        | 11.5     |
# | time/                 |          |
# |    fps                | 2363     |
# |    iterations         | 4800     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | -0.559   |
# |    explained_variance | 0.811    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.05    |
# |    value_loss         | 0.0593   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.2     |
# |    ep_rew_mean        | 10.7     |
# | time/                 |          |
# |    fps                | 2363     |
# |    iterations         | 4900     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 196000   |
# | train/                |          |
# |    entropy_loss       | -0.658   |
# |    explained_variance | 0.845    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.0698  |
# |    value_loss         | 0.0243   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.3     |
# |    ep_rew_mean        | 11.5     |
# | time/                 |          |
# |    fps                | 2363     |
# |    iterations         | 5000     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 200000   |
# | train/                |          |
# |    entropy_loss       | -0.524   |
# |    explained_variance | 0.749    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.05    |
# |    value_loss         | 0.0487   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.7     |
# |    ep_rew_mean        | 11.2     |
# | time/                 |          |
# |    fps                | 2363     |
# |    iterations         | 5100     |
# |    time_elapsed       | 86       |
# |    total_timesteps    | 204000   |
# | train/                |          |
# |    entropy_loss       | -0.535   |
# |    explained_variance | 0.739    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.00863  |
# |    value_loss         | 0.0277   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.9     |
# |    ep_rew_mean        | 11       |
# | time/                 |          |
# |    fps                | 2363     |
# |    iterations         | 5200     |
# |    time_elapsed       | 88       |
# |    total_timesteps    | 208000   |
# | train/                |          |
# |    entropy_loss       | -0.605   |
# |    explained_variance | 0.737    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.119   |
# |    value_loss         | 0.0417   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.1     |
# |    ep_rew_mean        | 11.3     |
# | time/                 |          |
# |    fps                | 2363     |
# |    iterations         | 5300     |
# |    time_elapsed       | 89       |
# |    total_timesteps    | 212000   |
# | train/                |          |
# |    entropy_loss       | -0.563   |
# |    explained_variance | 0.89     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.0184  |
# |    value_loss         | 0.0085   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.7     |
# |    ep_rew_mean        | 12       |
# | time/                 |          |
# |    fps                | 2364     |
# |    iterations         | 5400     |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 216000   |
# | train/                |          |
# |    entropy_loss       | -0.573   |
# |    explained_variance | 0.846    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.0896  |
# |    value_loss         | 0.0278   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.6     |
# |    ep_rew_mean        | 11.9     |
# | time/                 |          |
# |    fps                | 2363     |
# |    iterations         | 5500     |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 220000   |
# | train/                |          |
# |    entropy_loss       | -0.586   |
# |    explained_variance | 0.837    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.0743  |
# |    value_loss         | 0.032    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.1     |
# |    ep_rew_mean        | 11.4     |
# | time/                 |          |
# |    fps                | 2362     |
# |    iterations         | 5600     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 224000   |
# | train/                |          |
# |    entropy_loss       | -0.526   |
# |    explained_variance | 0.652    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.00223 |
# |    value_loss         | 0.0398   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.7     |
# |    ep_rew_mean        | 11.9     |
# | time/                 |          |
# |    fps                | 2362     |
# |    iterations         | 5700     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 228000   |
# | train/                |          |
# |    entropy_loss       | -0.531   |
# |    explained_variance | 0.353    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.564   |
# |    value_loss         | 0.519    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.3     |
# |    ep_rew_mean        | 11.4     |
# | time/                 |          |
# |    fps                | 2376     |
# |    iterations         | 5800     |
# |    time_elapsed       | 97       |
# |    total_timesteps    | 232000   |
# | train/                |          |
# |    entropy_loss       | -0.559   |
# |    explained_variance | 0.879    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.00206 |
# |    value_loss         | 0.00924  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.5     |
# |    ep_rew_mean        | 11.6     |
# | time/                 |          |
# |    fps                | 2380     |
# |    iterations         | 5900     |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 236000   |
# | train/                |          |
# |    entropy_loss       | -0.454   |
# |    explained_variance | 0.859    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.0292  |
# |    value_loss         | 0.0246   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.8     |
# |    ep_rew_mean        | 11.8     |
# | time/                 |          |
# |    fps                | 2380     |
# |    iterations         | 6000     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 240000   |
# | train/                |          |
# |    entropy_loss       | -0.568   |
# |    explained_variance | 0.946    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.0194  |
# |    value_loss         | 0.00539  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24       |
# |    ep_rew_mean        | 11.7     |
# | time/                 |          |
# |    fps                | 2379     |
# |    iterations         | 6100     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 244000   |
# | train/                |          |
# |    entropy_loss       | -0.532   |
# |    explained_variance | 0.813    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.0455  |
# |    value_loss         | 0.0177   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.5     |
# |    ep_rew_mean        | 11.8     |
# | time/                 |          |
# |    fps                | 2379     |
# |    iterations         | 6200     |
# |    time_elapsed       | 104      |
# |    total_timesteps    | 248000   |
# | train/                |          |
# |    entropy_loss       | -0.509   |
# |    explained_variance | 0.712    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.0252  |
# |    value_loss         | 0.0984   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.3     |
# |    ep_rew_mean        | -8.19    |
# | time/                 |          |
# |    fps                | 2380     |
# |    iterations         | 6300     |
# |    time_elapsed       | 105      |
# |    total_timesteps    | 252000   |
# | train/                |          |
# |    entropy_loss       | -0.643   |
# |    explained_variance | 0.958    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.308   |
# |    value_loss         | 1.73     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 10.1     |
# |    ep_rew_mean        | -3.91    |
# | time/                 |          |
# |    fps                | 2380     |
# |    iterations         | 6400     |
# |    time_elapsed       | 107      |
# |    total_timesteps    | 256000   |
# | train/                |          |
# |    entropy_loss       | -0.536   |
# |    explained_variance | 0.564    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.0611  |
# |    value_loss         | 0.241    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15       |
# |    ep_rew_mean        | -3.21    |
# | time/                 |          |
# |    fps                | 2379     |
# |    iterations         | 6500     |
# |    time_elapsed       | 109      |
# |    total_timesteps    | 260000   |
# | train/                |          |
# |    entropy_loss       | -0.475   |
# |    explained_variance | 0.912    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6499     |
# |    policy_loss        | 0.0468   |
# |    value_loss         | 0.0848   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.7     |
# |    ep_rew_mean        | -3.08    |
# | time/                 |          |
# |    fps                | 2378     |
# |    iterations         | 6600     |
# |    time_elapsed       | 110      |
# |    total_timesteps    | 264000   |
# | train/                |          |
# |    entropy_loss       | -0.447   |
# |    explained_variance | 0.987    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.00348  |
# |    value_loss         | 0.0105   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15.1     |
# |    ep_rew_mean        | -3.07    |
# | time/                 |          |
# |    fps                | 2378     |
# |    iterations         | 6700     |
# |    time_elapsed       | 112      |
# |    total_timesteps    | 268000   |
# | train/                |          |
# |    entropy_loss       | -0.436   |
# |    explained_variance | 0.962    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.0401   |
# |    value_loss         | 0.0197   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15.1     |
# |    ep_rew_mean        | -3.09    |
# | time/                 |          |
# |    fps                | 2378     |
# |    iterations         | 6800     |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 272000   |
# | train/                |          |
# |    entropy_loss       | -0.43    |
# |    explained_variance | 0.976    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.0333  |
# |    value_loss         | 0.0354   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.9     |
# |    ep_rew_mean        | -3.06    |
# | time/                 |          |
# |    fps                | 2378     |
# |    iterations         | 6900     |
# |    time_elapsed       | 116      |
# |    total_timesteps    | 276000   |
# | train/                |          |
# |    entropy_loss       | -0.466   |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.00687 |
# |    value_loss         | 0.00129  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.9     |
# |    ep_rew_mean        | -3.01    |
# | time/                 |          |
# |    fps                | 2377     |
# |    iterations         | 7000     |
# |    time_elapsed       | 117      |
# |    total_timesteps    | 280000   |
# | train/                |          |
# |    entropy_loss       | -0.485   |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.00693  |
# |    value_loss         | 0.00255  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15.7     |
# |    ep_rew_mean        | -3.45    |
# | time/                 |          |
# |    fps                | 2376     |
# |    iterations         | 7100     |
# |    time_elapsed       | 119      |
# |    total_timesteps    | 284000   |
# | train/                |          |
# |    entropy_loss       | -0.452   |
# |    explained_variance | 0.895    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.24    |
# |    value_loss         | 0.0712   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15.7     |
# |    ep_rew_mean        | -3.1     |
# | time/                 |          |
# |    fps                | 2376     |
# |    iterations         | 7200     |
# |    time_elapsed       | 121      |
# |    total_timesteps    | 288000   |
# | train/                |          |
# |    entropy_loss       | -0.454   |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7199     |
# |    policy_loss        | -0.016   |
# |    value_loss         | 0.00316  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.3     |
# |    ep_rew_mean        | -3.13    |
# | time/                 |          |
# |    fps                | 2376     |
# |    iterations         | 7300     |
# |    time_elapsed       | 122      |
# |    total_timesteps    | 292000   |
# | train/                |          |
# |    entropy_loss       | -0.457   |
# |    explained_variance | 0.923    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7299     |
# |    policy_loss        | -0.098   |
# |    value_loss         | 0.093    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15.9     |
# |    ep_rew_mean        | -3.46    |
# | time/                 |          |
# |    fps                | 2374     |
# |    iterations         | 7400     |
# |    time_elapsed       | 124      |
# |    total_timesteps    | 296000   |
# | train/                |          |
# |    entropy_loss       | -0.487   |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0.00142 |
# |    value_loss         | 0.00254  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.8     |
# |    ep_rew_mean        | -3.26    |
# | time/                 |          |
# |    fps                | 2374     |
# |    iterations         | 7500     |
# |    time_elapsed       | 126      |
# |    total_timesteps    | 300000   |
# | train/                |          |
# |    entropy_loss       | -0.447   |
# |    explained_variance | 0.654    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7499     |
# |    policy_loss        | -0.488   |
# |    value_loss         | 1.13     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.6     |
# |    ep_rew_mean        | -3.27    |
# | time/                 |          |
# |    fps                | 2373     |
# |    iterations         | 7600     |
# ...
# |    explained_variance | 0.77     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 22499    |
# |    policy_loss        | -0.291   |
# |    value_loss         | 0.402    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 17.2     |
# |    ep_rew_mean        | -3.1     |
# | time/                 |          |
# |    fps                | 2366     |
# |    iterations         | 22600    |
# |    time_elapsed       | 381      |
# |    total_timesteps    | 904000   |
# | train/                |          |
# |    entropy_loss       | -0.689   |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 22599    |
# |    policy_loss        | -0.0342  |
# |    value_loss         | 0.00285  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.7     |
# |    ep_rew_mean        | -2.78    |
# | time/                 |          |
# |    fps                | 2368     |
# |    iterations         | 22700    |
# |    time_elapsed       | 383      |
# |    total_timesteps    | 908000   |
# | train/                |          |
# |    entropy_loss       | -0.666   |
# |    explained_variance | 0.791    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 22699    |
# |    policy_loss        | -0.142   |
# |    value_loss         | 0.129    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.7     |
# |    ep_rew_mean        | -2.78    |
# | time/                 |          |
# |    fps                | 2368     |
# |    iterations         | 22800    |
# |    time_elapsed       | 385      |
# |    total_timesteps    | 912000   |
# | train/                |          |
# |    entropy_loss       | -0.651   |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 22799    |
# |    policy_loss        | -0.0055  |
# |    value_loss         | 0.012    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 16.9      |
# |    ep_rew_mean        | -2.73     |
# | time/                 |           |
# |    fps                | 2368      |
# |    iterations         | 22900     |
# |    time_elapsed       | 386       |
# |    total_timesteps    | 916000    |
# | train/                |           |
# |    entropy_loss       | -0.722    |
# |    explained_variance | 0.998     |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 22899     |
# |    policy_loss        | -0.000566 |
# |    value_loss         | 0.00281   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.7     |
# |    ep_rew_mean        | -2.78    |
# | time/                 |          |
# |    fps                | 2368     |
# |    iterations         | 23000    |
# |    time_elapsed       | 388      |
# |    total_timesteps    | 920000   |
# | train/                |          |
# |    entropy_loss       | -0.623   |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 22999    |
# |    policy_loss        | -0.00618 |
# |    value_loss         | 0.00109  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 17       |
# |    ep_rew_mean        | -2.83    |
# | time/                 |          |
# |    fps                | 2368     |
# |    iterations         | 23100    |
# |    time_elapsed       | 390      |
# |    total_timesteps    | 924000   |
# | train/                |          |
# |    entropy_loss       | -0.558   |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 23099    |
# |    policy_loss        | -0.00474 |
# |    value_loss         | 0.000808 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.4     |
# |    ep_rew_mean        | -2.81    |
# | time/                 |          |
# |    fps                | 2368     |
# |    iterations         | 23200    |
# |    time_elapsed       | 391      |
# |    total_timesteps    | 928000   |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0.933    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 23199    |
# |    policy_loss        | -0.127   |
# |    value_loss         | 0.0516   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.9     |
# |    ep_rew_mean        | -2.82    |
# | time/                 |          |
# |    fps                | 2367     |
# |    iterations         | 23300    |
# |    time_elapsed       | 393      |
# |    total_timesteps    | 932000   |
# | train/                |          |
# |    entropy_loss       | -0.676   |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 23299    |
# |    policy_loss        | -0.00751 |
# |    value_loss         | 0.00153  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.6     |
# |    ep_rew_mean        | -2.79    |
# | time/                 |          |
# |    fps                | 2367     |
# |    iterations         | 23400    |
# |    time_elapsed       | 395      |
# |    total_timesteps    | 936000   |
# | train/                |          |
# |    entropy_loss       | -0.584   |
# |    explained_variance | 0.899    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 23399    |
# |    policy_loss        | -0.0917  |
# |    value_loss         | 0.124    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 17       |
# |    ep_rew_mean        | -2.93    |
# | time/                 |          |
# |    fps                | 2367     |
# |    iterations         | 23500    |
# |    time_elapsed       | 397      |
# |    total_timesteps    | 940000   |
# | train/                |          |
# |    entropy_loss       | -0.74    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 23499    |
# |    policy_loss        | 0.00252  |
# |    value_loss         | 0.00198  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.7     |
# |    ep_rew_mean        | -2.76    |
# | time/                 |          |
# |    fps                | 2367     |
# |    iterations         | 23600    |
# |    time_elapsed       | 398      |
# |    total_timesteps    | 944000   |
# | train/                |          |
# |    entropy_loss       | -0.674   |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 23599    |
# |    policy_loss        | -0.0159  |
# |    value_loss         | 0.0033   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.9     |
# |    ep_rew_mean        | -2.75    |
# | time/                 |          |
# |    fps                | 2367     |
# |    iterations         | 23700    |
# |    time_elapsed       | 400      |
# |    total_timesteps    | 948000   |
# | train/                |          |
# |    entropy_loss       | -0.569   |
# |    explained_variance | 0.882    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 23699    |
# |    policy_loss        | -0.249   |
# |    value_loss         | 0.239    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.9     |
# |    ep_rew_mean        | -2.92    |
# | time/                 |          |
# |    fps                | 2367     |
# |    iterations         | 23800    |
# |    time_elapsed       | 402      |
# |    total_timesteps    | 952000   |
# | train/                |          |
# |    entropy_loss       | -0.778   |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 23799    |
# |    policy_loss        | 0.0104   |
# |    value_loss         | 0.00121  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.5     |
# |    ep_rew_mean        | -2.78    |
# | time/                 |          |
# |    fps                | 2366     |
# |    iterations         | 23900    |
# |    time_elapsed       | 403      |
# |    total_timesteps    | 956000   |
# | train/                |          |
# |    entropy_loss       | -0.613   |
# |    explained_variance | 0.991    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 23899    |
# |    policy_loss        | 0.0128   |
# |    value_loss         | 0.00349  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.8     |
# |    ep_rew_mean        | -2.75    |
# | time/                 |          |
# |    fps                | 2367     |
# |    iterations         | 24000    |
# |    time_elapsed       | 405      |
# |    total_timesteps    | 960000   |
# | train/                |          |
# |    entropy_loss       | -0.708   |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 23999    |
# |    policy_loss        | 0.00088  |
# |    value_loss         | 0.00159  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.5     |
# |    ep_rew_mean        | -2.76    |
# | time/                 |          |
# |    fps                | 2367     |
# |    iterations         | 24100    |
# |    time_elapsed       | 407      |
# |    total_timesteps    | 964000   |
# | train/                |          |
# |    entropy_loss       | -0.679   |
# |    explained_variance | 0.91     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 24099    |
# |    policy_loss        | -0.0698  |
# |    value_loss         | 0.0496   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 17.1     |
# |    ep_rew_mean        | -3.16    |
# | time/                 |          |
# |    fps                | 2367     |
# |    iterations         | 24200    |
# |    time_elapsed       | 408      |
# |    total_timesteps    | 968000   |
# | train/                |          |
# |    entropy_loss       | -0.62    |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 24199    |
# |    policy_loss        | 0.0105   |
# |    value_loss         | 0.00685  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 17       |
# |    ep_rew_mean        | -2.77    |
# | time/                 |          |
# |    fps                | 2366     |
# |    iterations         | 24300    |
# |    time_elapsed       | 410      |
# |    total_timesteps    | 972000   |
# | train/                |          |
# |    entropy_loss       | -0.673   |
# |    explained_variance | 0.799    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 24299    |
# |    policy_loss        | -0.415   |
# |    value_loss         | 0.344    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 17.4     |
# |    ep_rew_mean        | -3.25    |
# | time/                 |          |
# |    fps                | 2366     |
# |    iterations         | 24400    |
# |    time_elapsed       | 412      |
# |    total_timesteps    | 976000   |
# | train/                |          |
# |    entropy_loss       | -0.79    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 24399    |
# |    policy_loss        | -0.0148  |
# |    value_loss         | 0.00203  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.7     |
# |    ep_rew_mean        | -2.83    |
# | time/                 |          |
# |    fps                | 2366     |
# |    iterations         | 24500    |
# |    time_elapsed       | 414      |
# |    total_timesteps    | 980000   |
# | train/                |          |
# |    entropy_loss       | -0.682   |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 24499    |
# |    policy_loss        | 0.0154   |
# |    value_loss         | 0.00206  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.7     |
# |    ep_rew_mean        | -2.8     |
# | time/                 |          |
# |    fps                | 2366     |
# |    iterations         | 24600    |
# |    time_elapsed       | 415      |
# |    total_timesteps    | 984000   |
# | train/                |          |
# |    entropy_loss       | -0.648   |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 24599    |
# |    policy_loss        | 0.0132   |
# |    value_loss         | 0.00199  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.7     |
# |    ep_rew_mean        | -2.76    |
# | time/                 |          |
# |    fps                | 2367     |
# |    iterations         | 24700    |
# |    time_elapsed       | 417      |
# |    total_timesteps    | 988000   |
# | train/                |          |
# |    entropy_loss       | -0.559   |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 24699    |
# |    policy_loss        | -0.00116 |
# |    value_loss         | 0.000818 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.2     |
# |    ep_rew_mean        | -2.88    |
# | time/                 |          |
# |    fps                | 2369     |
# |    iterations         | 24800    |
# |    time_elapsed       | 418      |
# |    total_timesteps    | 992000   |
# | train/                |          |
# |    entropy_loss       | -0.656   |
# |    explained_variance | 0.599    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 24799    |
# |    policy_loss        | -0.034   |
# |    value_loss         | 3.73     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.8     |
# |    ep_rew_mean        | -2.77    |
# | time/                 |          |
# |    fps                | 2369     |
# |    iterations         | 24900    |
# |    time_elapsed       | 420      |
# |    total_timesteps    | 996000   |
# | train/                |          |
# |    entropy_loss       | -0.66    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 24899    |
# |    policy_loss        | 0.0114   |
# |    value_loss         | 0.00263  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.6     |
# |    ep_rew_mean        | -2.79    |
# | time/                 |          |
# |    fps                | 2369     |
# |    iterations         | 25000    |
# |    time_elapsed       | 422      |
# |    total_timesteps    | 1000000  |
# | train/                |          |
# |    entropy_loss       | -0.609   |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 24999    |
# |    policy_loss        | -0.0111  |
# |    value_loss         | 0.00462  |
# ------------------------------------

# %%
# Test the trained agent
# using the vecenv
obs = vec_env.reset()
n_steps = 20
for step in range(n_steps):
    action, _ = model.predict(obs, deterministic=True)
    print(f"Step {step + 1} Action {action}")
    obs, reward, done, info = vec_env.step(action)
    print("reward=", reward)
    vec_env.render()
# Out:
# Step 1 Action [2 2 2 2 2 2 2 2]
# reward= [0.10454353 0.10454353 0.10454353 0.10454353 0.10454353 0.10454353
#  0.10454353 0.10454353]
# Step 2 Action [4 4 4 4 4 4 4 4]
# reward= [0.15242527 0.15242527 0.15242527 0.15242527 0.15242527 0.15242527
#  0.15242527 0.15242527]
# Step 3 Action [4 4 4 4 4 4 4 4]
# reward= [0.04273289 0.04273289 0.04273289 0.04273289 0.04273289 0.04273289
#  0.04273289 0.04273289]
# Step 4 Action [0 0 0 0 0 0 0 0]
# reward= [0.26143742 0.26143742 0.26143742 0.26143742 0.26143742 0.26143742
#  0.26143742 0.26143742]
# Step 5 Action [4 4 4 4 4 4 4 4]
# reward= [-0.02939921 -0.02939921 -0.02939921 -0.02939921 -0.02939921 -0.02939921
#  -0.02939921 -0.02939921]
# Step 6 Action [0 0 0 0 0 0 0 0]
# reward= [0.20489605 0.20489605 0.20489605 0.20489605 0.20489605 0.20489605
#  0.20489605 0.20489605]
# Step 7 Action [0 0 0 0 0 0 0 0]
# reward= [0.07642822 0.07642822 0.07642822 0.07642822 0.07642822 0.07642822
#  0.07642822 0.07642822]
# Step 8 Action [2 2 2 2 2 2 2 2]
# reward= [0.35251176 0.35251176 0.35251176 0.35251176 0.35251176 0.35251176
#  0.35251176 0.35251176]
# Step 9 Action [0 0 0 0 0 0 0 0]
# reward= [-0.00269178 -0.00269178 -0.00269178 -0.00269178 -0.00269178 -0.00269178
#  -0.00269178 -0.00269178]
# Step 10 Action [4 4 4 4 4 4 4 4]
# reward= [0.05750627 0.05750627 0.05750627 0.05750627 0.05750627 0.05750627
#  0.05750627 0.05750627]
# Step 11 Action [2 2 2 2 2 2 2 2]
# reward= [0.39275363 0.39275363 0.39275363 0.39275363 0.39275363 0.39275363
#  0.39275363 0.39275363]
# Step 12 Action [0 0 0 0 0 0 0 0]
# reward= [-0.04246675 -0.04246675 -0.04246675 -0.04246675 -0.04246675 -0.04246675
#  -0.04246675 -0.04246675]
# Step 13 Action [2 2 2 2 2 2 2 2]
# reward= [0.33588713 0.33588713 0.33588713 0.33588713 0.33588713 0.33588713
#  0.33588713 0.33588713]
# Step 14 Action [4 4 4 4 4 4 4 4]
# reward= [0.14434469 0.14434469 0.14434469 0.14434469 0.14434469 0.14434469
#  0.14434469 0.14434469]
# Step 15 Action [0 0 0 0 0 0 0 0]
# reward= [-0.10842583 -0.10842583 -0.10842583 -0.10842583 -0.10842583 -0.10842583
#  -0.10842583 -0.10842583]
# Step 16 Action [2 2 2 2 2 2 2 2]
# reward= [0.38949808 0.38949808 0.38949808 0.38949808 0.38949808 0.38949808
#  0.38949808 0.38949808]
# Step 17 Action [1 1 1 1 1 1 1 1]
# reward= [-5. -5. -5. -5. -5. -5. -5. -5.]
# Step 18 Action [2 2 2 2 2 2 2 2]
# reward= [0.10454353 0.10454353 0.10454353 0.10454353 0.10454353 0.10454353
#  0.10454353 0.10454353]
# Step 19 Action [4 4 4 4 4 4 4 4]
# reward= [0.15242527 0.15242527 0.15242527 0.15242527 0.15242527 0.15242527
#  0.15242527 0.15242527]
# Step 20 Action [4 4 4 4 4 4 4 4]
# reward= [0.04273289 0.04273289 0.04273289 0.04273289 0.04273289 0.04273289
#  0.04273289 0.04273289]
# C:\Users\zhech\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:244: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
