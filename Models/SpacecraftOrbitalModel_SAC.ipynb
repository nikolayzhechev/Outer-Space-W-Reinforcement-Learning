# %% [markdown]
# Basic environemnt usage with Gymnasium, Stable Baselines3 and SAC

# %%
import gymnasium as gym
from stable_baselines3 import SAC
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.env_util import make_vec_env
import os

# %%
# Import environment creator function
from Environment_Creator import env_creator
# Instantiate one of the custom environments
config = None
orbital_env = env_creator(config, "interplanetary")
# Out:
# C:\Users\zhech\Desktop\Softuni\Deep Learning\Project\Models\SpacecraftInterplanetaryEnv.py:22: TimeScaleWarning: Input time was converted to scale='tdb' with value [datetime.datetime(2025, 2, 6, 17, 43, 8, 369306)]. Use Time(..., scale='tdb') instead.
#   self.initial_orbit = Orbit.from_ephem(Earth, Ephem.from_body(Earth, self.epoch), self.epoch)  # Earth's current heliocentric orbit
# C:\Users\zhech\Desktop\Softuni\Deep Learning\Project\Models\SpacecraftInterplanetaryEnv.py:23: TimeScaleWarning: Input time was converted to scale='tdb' with value [datetime.datetime(2025, 2, 6, 17, 43, 8, 369306)]. Use Time(..., scale='tdb') instead.
#   self.target_orbit = Orbit.from_ephem(Mars, Ephem.from_body(Mars, self.epoch), self.epoch)    # Mars' orbit around the Sun
# C:\Users\zhech\AppData\Local\Programs\Python\Python310\lib\site-packages\gymnasium\spaces\box.py:235: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# C:\Users\zhech\AppData\Local\Programs\Python\Python310\lib\site-packages\gymnasium\spaces\box.py:305: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(

# %%
# Register the custom environment with Gym
gym.register(
    id="SpacecraftInterplanetaryEnv-v0",
    entry_point=lambda config: env_creator(config, "interplanetary")
)
# Verify environment registry
gym.pprint_registry()
# Out:
# ===== classic_control =====
# Acrobot-v1                  CartPole-v0                 CartPole-v1
# MountainCar-v0              MountainCarContinuous-v0    Pendulum-v1
# ===== phys2d =====
# phys2d/CartPole-v0          phys2d/CartPole-v1          phys2d/Pendulum-v0
# ===== box2d =====
# BipedalWalker-v3            BipedalWalkerHardcore-v3    CarRacing-v3
# LunarLander-v3              LunarLanderContinuous-v3
# ===== toy_text =====
# Blackjack-v1                CliffWalking-v0             FrozenLake-v1
# FrozenLake8x8-v1            Taxi-v3
# ===== tabular =====
# tabular/Blackjack-v0        tabular/CliffWalking-v0
# ===== mujoco =====
# Ant-v2                      Ant-v3                      Ant-v4
# Ant-v5                      HalfCheetah-v2              HalfCheetah-v3
# HalfCheetah-v4              HalfCheetah-v5              Hopper-v2
# Hopper-v3                   Hopper-v4                   Hopper-v5
# Humanoid-v2                 Humanoid-v3                 Humanoid-v4
# Humanoid-v5                 HumanoidStandup-v2          HumanoidStandup-v4
# HumanoidStandup-v5          InvertedDoublePendulum-v2   InvertedDoublePendulum-v4
# InvertedDoublePendulum-v5   InvertedPendulum-v2         InvertedPendulum-v4
# InvertedPendulum-v5         Pusher-v2                   Pusher-v4
# Pusher-v5                   Reacher-v2                  Reacher-v4
# Reacher-v5                  Swimmer-v2                  Swimmer-v3
# Swimmer-v4                  Swimmer-v5                  Walker2d-v2
# Walker2d-v3                 Walker2d-v4                 Walker2d-v5
# ===== None =====
# GymV21Environment-v0        GymV26Environment-v0        SpacecraftInterplanetaryEnv-v0

# %%
# Make our environment
gym_env = gym.make("SpacecraftInterplanetaryEnv-v0", config=config)
gym_env = Monitor(gym_env)  # Logs training progress

# Instantiate the env
vec_env = make_vec_env("SpacecraftInterplanetaryEnv-v0", n_envs=1, env_kwargs=dict(config=config))
# Out:
# C:\Users\zhech\Desktop\Softuni\Deep Learning\Project\Models\SpacecraftInterplanetaryEnv.py:22: TimeScaleWarning: Input time was converted to scale='tdb' with value [datetime.datetime(2025, 2, 6, 17, 50, 36, 15952)]. Use Time(..., scale='tdb') instead.
#   self.initial_orbit = Orbit.from_ephem(Earth, Ephem.from_body(Earth, self.epoch), self.epoch)  # Earth's current heliocentric orbit
# C:\Users\zhech\Desktop\Softuni\Deep Learning\Project\Models\SpacecraftInterplanetaryEnv.py:23: TimeScaleWarning: Input time was converted to scale='tdb' with value [datetime.datetime(2025, 2, 6, 17, 50, 36, 15952)]. Use Time(..., scale='tdb') instead.
#   self.target_orbit = Orbit.from_ephem(Mars, Ephem.from_body(Mars, self.epoch), self.epoch)    # Mars' orbit around the Sun
# C:\Users\zhech\Desktop\Softuni\Deep Learning\Project\Models\SpacecraftInterplanetaryEnv.py:22: TimeScaleWarning: Input time was converted to scale='tdb' with value [datetime.datetime(2025, 2, 6, 17, 50, 36, 20933)]. Use Time(..., scale='tdb') instead.
#   self.initial_orbit = Orbit.from_ephem(Earth, Ephem.from_body(Earth, self.epoch), self.epoch)  # Earth's current heliocentric orbit
# C:\Users\zhech\Desktop\Softuni\Deep Learning\Project\Models\SpacecraftInterplanetaryEnv.py:23: TimeScaleWarning: Input time was converted to scale='tdb' with value [datetime.datetime(2025, 2, 6, 17, 50, 36, 20933)]. Use Time(..., scale='tdb') instead.
#   self.target_orbit = Orbit.from_ephem(Mars, Ephem.from_body(Mars, self.epoch), self.epoch)    # Mars' orbit around the Sun

# %%
# Check env support with baselines3
from stable_baselines3.common.env_checker import check_env
check_env(gym_env)

# %%
# Define SAC model with hyperparameters
# RUN_01
model = SAC(
    "MlpPolicy",  # Uses a neural network to approximate the policy
    gym_env,
    learning_rate=3e-4,
    buffer_size=1000000,  # Large replay buffer
    batch_size=256,  # Larger batch size helps with training stability
    tau=0.005,  # Polyak averaging coefficient (for target network updates)
    gamma=0.99,  # Discount factor
    train_freq=10,  # Train every 10 steps
    gradient_steps=10,  # Update the model for 10 steps per training iteration
    verbose=1,  # Print training info
    device="auto",  # Use GPU if available
)

# %%
# RUN_02
model = SAC(
    "MlpPolicy",  # Uses a neural network to approximate the policy
    gym_env,
    learning_rate=3e-4,
    buffer_size=100000,  # Large replay buffer
    batch_size=500,  # Larger batch size helps with training stability
    tau=0.005,  # Polyak averaging coefficient (for target network updates)
    gamma=0.99,  # Discount factor
    train_freq=10,  # Train every 10 steps
    gradient_steps=10,  # Update the model for 10 steps per training iteration
    verbose=1,  # Print training info
    device="auto",  # Use GPU if available
)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
# Setup model checkpointing
checkpoint_callback = CheckpointCallback(
    save_freq=50000,  # Save model every 50,000 steps
    save_path="./checkpoints/",
    name_prefix="sac_spacecraft",
    save_replay_buffer=True,
    save_vecnormalize=True,
)

# Train the agent for 1 million timesteps (longer training for better results)
model.learn(total_timesteps=100_000, callback=checkpoint_callback)

# Save final model
model.save("sac_spacecraft_final")
print("Training complete. Model saved.")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -2.4e+03 |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 906      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 85       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.4     |
# |    ep_rew_mean     | -2e+03   |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 73       |
# |    time_elapsed    | 1        |
# |    total_timesteps | 139      |
# | train/             |          |
# |    actor_loss      | 2.29e+06 |
# |    critic_loss     | 4.55e+11 |
# |    ent_coef        | 1.01     |
# |    ent_coef_loss   | -0.538   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30       |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 15.6      |
# |    ep_rew_mean     | -1.82e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 40        |
# |    time_elapsed    | 4         |
# |    total_timesteps | 187       |
# | train/             |           |
# |    actor_loss      | 1.78e+06  |
# |    critic_loss     | 2.11e+11  |
# |    ent_coef        | 1.02      |
# |    ent_coef_loss   | -1.64     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 80        |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 14.7      |
# |    ep_rew_mean     | -1.73e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 31        |
# |    time_elapsed    | 7         |
# |    total_timesteps | 235       |
# | train/             |           |
# |    actor_loss      | 1.76e+06  |
# |    critic_loss     | 2.07e+11  |
# |    ent_coef        | 1.04      |
# |    ent_coef_loss   | -2.73     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 130       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 14.2      |
# |    ep_rew_mean     | -1.68e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 27        |
# |    time_elapsed    | 10        |
# |    total_timesteps | 283       |
# | train/             |           |
# |    actor_loss      | 1.75e+06  |
# |    critic_loss     | 2.13e+11  |
# |    ent_coef        | 1.05      |
# |    ent_coef_loss   | -3.83     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 180       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 13.8      |
# |    ep_rew_mean     | -1.64e+03 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 26        |
# |    time_elapsed    | 12        |
# |    total_timesteps | 331       |
# | train/             |           |
# |    actor_loss      | 1.7e+06   |
# |    critic_loss     | 1.94e+11  |
# |    ent_coef        | 1.07      |
# |    ent_coef_loss   | -4.93     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 230       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 13.5      |
# |    ep_rew_mean     | -1.61e+03 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 25        |
# |    time_elapsed    | 14        |
# |    total_timesteps | 379       |
# | train/             |           |
# |    actor_loss      | 1.65e+06  |
# |    critic_loss     | 1.93e+11  |
# |    ent_coef        | 1.08      |
# |    ent_coef_loss   | -5.81     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 270       |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.3     |
# |    ep_rew_mean     | -1.6e+03 |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 24       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 427      |
# | train/             |          |
# |    actor_loss      | 1.61e+06 |
# |    critic_loss     | 1.98e+11 |
# |    ent_coef        | 1.1      |
# |    ent_coef_loss   | -6.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 320      |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 13.2      |
# |    ep_rew_mean     | -1.58e+03 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 23        |
# |    time_elapsed    | 20        |
# |    total_timesteps | 475       |
# | train/             |           |
# |    actor_loss      | 1.62e+06  |
# |    critic_loss     | 1.99e+11  |
# |    ent_coef        | 1.12      |
# |    ent_coef_loss   | -8        |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 370       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 13.1      |
# |    ep_rew_mean     | -1.57e+03 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 22        |
# |    time_elapsed    | 22        |
# |    total_timesteps | 523       |
# | train/             |           |
# |    actor_loss      | 1.52e+06  |
# |    critic_loss     | 1.92e+11  |
# |    ent_coef        | 1.13      |
# |    ent_coef_loss   | -9.1      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 420       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 13        |
# |    ep_rew_mean     | -1.56e+03 |
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 22        |
# |    time_elapsed    | 25        |
# |    total_timesteps | 571       |
# | train/             |           |
# |    actor_loss      | 1.49e+06  |
# |    critic_loss     | 1.88e+11  |
# |    ent_coef        | 1.15      |
# |    ent_coef_loss   | -10.2     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 470       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12.9      |
# |    ep_rew_mean     | -1.55e+03 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 21        |
# |    time_elapsed    | 28        |
# |    total_timesteps | 619       |
# | train/             |           |
# |    actor_loss      | 1.5e+06   |
# |    critic_loss     | 1.69e+11  |
# |    ent_coef        | 1.16      |
# |    ent_coef_loss   | -11.1     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 510       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12.8      |
# |    ep_rew_mean     | -1.54e+03 |
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 21        |
# |    time_elapsed    | 31        |
# |    total_timesteps | 667       |
# | train/             |           |
# |    actor_loss      | 1.47e+06  |
# |    critic_loss     | 1.76e+11  |
# |    ent_coef        | 1.18      |
# |    ent_coef_loss   | -12.2     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 560       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12.8      |
# |    ep_rew_mean     | -1.54e+03 |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 20        |
# |    time_elapsed    | 34        |
# |    total_timesteps | 715       |
# | train/             |           |
# |    actor_loss      | 1.41e+06  |
# |    critic_loss     | 1.7e+11   |
# |    ent_coef        | 1.2       |
# |    ent_coef_loss   | -13.3     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 610       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12.7      |
# |    ep_rew_mean     | -1.53e+03 |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 20        |
# |    time_elapsed    | 37        |
# |    total_timesteps | 763       |
# | train/             |           |
# |    actor_loss      | 1.43e+06  |
# |    critic_loss     | 1.58e+11  |
# |    ent_coef        | 1.22      |
# |    ent_coef_loss   | -14.4     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 660       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12.7      |
# |    ep_rew_mean     | -1.53e+03 |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 20        |
# |    time_elapsed    | 40        |
# |    total_timesteps | 811       |
# | train/             |           |
# |    actor_loss      | 1.4e+06   |
# |    critic_loss     | 1.67e+11  |
# |    ent_coef        | 1.24      |
# |    ent_coef_loss   | -15.5     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 710       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12.6      |
# |    ep_rew_mean     | -1.52e+03 |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 20        |
# |    time_elapsed    | 42        |
# |    total_timesteps | 859       |
# | train/             |           |
# |    actor_loss      | 1.34e+06  |
# |    critic_loss     | 1.41e+11  |
# |    ent_coef        | 1.25      |
# |    ent_coef_loss   | -16.3     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 750       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12.6      |
# |    ep_rew_mean     | -1.52e+03 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 19        |
# |    time_elapsed    | 45        |
# |    total_timesteps | 907       |
# | train/             |           |
# |    actor_loss      | 1.34e+06  |
# |    critic_loss     | 1.45e+11  |
# |    ent_coef        | 1.27      |
# |    ent_coef_loss   | -17.4     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 800       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12.6      |
# |    ep_rew_mean     | -1.52e+03 |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 19        |
# |    time_elapsed    | 48        |
# |    total_timesteps | 955       |
# | train/             |           |
# |    actor_loss      | 1.31e+06  |
# |    critic_loss     | 1.47e+11  |
# |    ent_coef        | 1.29      |
# |    ent_coef_loss   | -18.5     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 850       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12.5      |
# |    ep_rew_mean     | -1.51e+03 |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 19        |
# |    time_elapsed    | 50        |
# |    total_timesteps | 1003      |
# | train/             |           |
# |    actor_loss      | 1.28e+06  |
# |    critic_loss     | 1.42e+11  |
# |    ent_coef        | 1.31      |
# |    ent_coef_loss   | -19.6     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 900       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12.5      |
# |    ep_rew_mean     | -1.51e+03 |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 19        |
# |    time_elapsed    | 53        |
# |    total_timesteps | 1051      |
# | train/             |           |
# |    actor_loss      | 1.25e+06  |
# |    critic_loss     | 1.29e+11  |
# |    ent_coef        | 1.33      |
# |    ent_coef_loss   | -20.7     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 950       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12.5      |
# |    ep_rew_mean     | -1.51e+03 |
# | time/              |           |
# |    episodes        | 88        |
# |    fps             | 19        |
# |    time_elapsed    | 55        |
# |    total_timesteps | 1099      |
# | train/             |           |
# |    actor_loss      | 1.18e+06  |
# |    critic_loss     | 1.29e+11  |
# |    ent_coef        | 1.34      |
# |    ent_coef_loss   | -21.6     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 990       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12.5      |
# |    ep_rew_mean     | -1.51e+03 |
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 19        |
# |    time_elapsed    | 58        |
# |    total_timesteps | 1147      |
# | train/             |           |
# |    actor_loss      | 1.21e+06  |
# |    critic_loss     | 1.37e+11  |
# |    ent_coef        | 1.36      |
# |    ent_coef_loss   | -22.7     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1040      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12.4      |
# |    ep_rew_mean     | -1.51e+03 |
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 19        |
# |    time_elapsed    | 61        |
# |    total_timesteps | 1195      |
# | train/             |           |
# |    actor_loss      | 1.17e+06  |
# |    critic_loss     | 1.09e+11  |
# |    ent_coef        | 1.38      |
# |    ent_coef_loss   | -23.8     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1090      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.4     |
# |    ep_rew_mean     | -1.5e+03 |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 19       |
# |    time_elapsed    | 63       |
# |    total_timesteps | 1243     |
# | train/             |          |
# |    actor_loss      | 1.11e+06 |
# |    critic_loss     | 1.04e+11 |
# |    ent_coef        | 1.41     |
# |    ent_coef_loss   | -24.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1140     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12.1      |
# |    ep_rew_mean     | -1.47e+03 |
# | time/              |           |
# |    episodes        | 104       |
# |    fps             | 19        |
# |    time_elapsed    | 67        |
# |    total_timesteps | 1291      |
# | train/             |           |
# |    actor_loss      | 1.13e+06  |
# |    critic_loss     | 1.05e+11  |
# |    ent_coef        | 1.43      |
# |    ent_coef_loss   | -26       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1190      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 108       |
# |    fps             | 19        |
# |    time_elapsed    | 69        |
# |    total_timesteps | 1339      |
# | train/             |           |
# |    actor_loss      | 1.09e+06  |
# |    critic_loss     | 9.1e+10   |
# |    ent_coef        | 1.44      |
# |    ent_coef_loss   | -26.9     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1230      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 112       |
# |    fps             | 19        |
# |    time_elapsed    | 72        |
# |    total_timesteps | 1387      |
# | train/             |           |
# |    actor_loss      | 1.05e+06  |
# |    critic_loss     | 9.43e+10  |
# |    ent_coef        | 1.47      |
# |    ent_coef_loss   | -28       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1280      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 116       |
# |    fps             | 19        |
# |    time_elapsed    | 75        |
# |    total_timesteps | 1435      |
# | train/             |           |
# |    actor_loss      | 1.05e+06  |
# |    critic_loss     | 9.33e+10  |
# |    ent_coef        | 1.49      |
# |    ent_coef_loss   | -29.1     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1330      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 120       |
# |    fps             | 18        |
# |    time_elapsed    | 78        |
# |    total_timesteps | 1483      |
# | train/             |           |
# |    actor_loss      | 1.02e+06  |
# |    critic_loss     | 8.85e+10  |
# |    ent_coef        | 1.51      |
# |    ent_coef_loss   | -30.2     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1380      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 124       |
# |    fps             | 19        |
# |    time_elapsed    | 80        |
# |    total_timesteps | 1531      |
# | train/             |           |
# |    actor_loss      | 1.03e+06  |
# |    critic_loss     | 8.63e+10  |
# |    ent_coef        | 1.53      |
# |    ent_coef_loss   | -31.3     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1430      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 128       |
# |    fps             | 19        |
# |    time_elapsed    | 82        |
# |    total_timesteps | 1579      |
# | train/             |           |
# |    actor_loss      | 9.74e+05  |
# |    critic_loss     | 8.28e+10  |
# |    ent_coef        | 1.55      |
# |    ent_coef_loss   | -32.2     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1470      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 132       |
# |    fps             | 18        |
# |    time_elapsed    | 85        |
# |    total_timesteps | 1627      |
# | train/             |           |
# |    actor_loss      | 9.42e+05  |
# |    critic_loss     | 7.71e+10  |
# |    ent_coef        | 1.58      |
# |    ent_coef_loss   | -33.3     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1520      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 136       |
# |    fps             | 18        |
# |    time_elapsed    | 88        |
# |    total_timesteps | 1675      |
# | train/             |           |
# |    actor_loss      | 9.35e+05  |
# |    critic_loss     | 8.37e+10  |
# |    ent_coef        | 1.6       |
# |    ent_coef_loss   | -34.3     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1570      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 140       |
# |    fps             | 18        |
# |    time_elapsed    | 91        |
# |    total_timesteps | 1723      |
# | train/             |           |
# |    actor_loss      | 9.53e+05  |
# |    critic_loss     | 7.48e+10  |
# |    ent_coef        | 1.62      |
# |    ent_coef_loss   | -35.4     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1620      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 144       |
# |    fps             | 18        |
# |    time_elapsed    | 94        |
# |    total_timesteps | 1771      |
# | train/             |           |
# |    actor_loss      | 8.9e+05   |
# |    critic_loss     | 7e+10     |
# |    ent_coef        | 1.65      |
# |    ent_coef_loss   | -36.5     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1670      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 148       |
# |    fps             | 18        |
# |    time_elapsed    | 96        |
# |    total_timesteps | 1819      |
# | train/             |           |
# |    actor_loss      | 8.95e+05  |
# |    critic_loss     | 7.23e+10  |
# |    ent_coef        | 1.67      |
# |    ent_coef_loss   | -37.4     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1710      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 152       |
# |    fps             | 18        |
# |    time_elapsed    | 99        |
# |    total_timesteps | 1867      |
# | train/             |           |
# |    actor_loss      | 8.72e+05  |
# |    critic_loss     | 6.61e+10  |
# |    ent_coef        | 1.69      |
# |    ent_coef_loss   | -38.5     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1760      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 156       |
# |    fps             | 18        |
# |    time_elapsed    | 102       |
# |    total_timesteps | 1915      |
# | train/             |           |
# |    actor_loss      | 8.59e+05  |
# |    critic_loss     | 6.81e+10  |
# |    ent_coef        | 1.72      |
# |    ent_coef_loss   | -39.6     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1810      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 160       |
# |    fps             | 18        |
# |    time_elapsed    | 105       |
# |    total_timesteps | 1963      |
# | train/             |           |
# |    actor_loss      | 8.6e+05   |
# |    critic_loss     | 6.01e+10  |
# |    ent_coef        | 1.74      |
# |    ent_coef_loss   | -40.7     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1860      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 164       |
# |    fps             | 18        |
# |    time_elapsed    | 109       |
# |    total_timesteps | 2011      |
# | train/             |           |
# |    actor_loss      | 8.13e+05  |
# |    critic_loss     | 5.81e+10  |
# |    ent_coef        | 1.77      |
# |    ent_coef_loss   | -41.8     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1910      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 168       |
# |    fps             | 18        |
# |    time_elapsed    | 111       |
# |    total_timesteps | 2059      |
# | train/             |           |
# |    actor_loss      | 7.73e+05  |
# |    critic_loss     | 5.28e+10  |
# |    ent_coef        | 1.79      |
# |    ent_coef_loss   | -42.7     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1950      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 172       |
# |    fps             | 18        |
# |    time_elapsed    | 113       |
# |    total_timesteps | 2107      |
# | train/             |           |
# |    actor_loss      | 7.75e+05  |
# |    critic_loss     | 5.71e+10  |
# |    ent_coef        | 1.82      |
# |    ent_coef_loss   | -43.8     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2000      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 176       |
# |    fps             | 18        |
# |    time_elapsed    | 116       |
# |    total_timesteps | 2155      |
# | train/             |           |
# |    actor_loss      | 7.57e+05  |
# |    critic_loss     | 5.05e+10  |
# |    ent_coef        | 1.85      |
# |    ent_coef_loss   | -44.9     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2050      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 180       |
# |    fps             | 18        |
# |    time_elapsed    | 119       |
# |    total_timesteps | 2203      |
# | train/             |           |
# |    actor_loss      | 7.8e+05   |
# |    critic_loss     | 6.07e+10  |
# |    ent_coef        | 1.87      |
# |    ent_coef_loss   | -46       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2100      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 184       |
# |    fps             | 18        |
# |    time_elapsed    | 122       |
# |    total_timesteps | 2251      |
# | train/             |           |
# |    actor_loss      | 7.29e+05  |
# |    critic_loss     | 4.51e+10  |
# |    ent_coef        | 1.9       |
# |    ent_coef_loss   | -47.1     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2150      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 188       |
# |    fps             | 18        |
# |    time_elapsed    | 124       |
# |    total_timesteps | 2299      |
# | train/             |           |
# |    actor_loss      | 7.31e+05  |
# |    critic_loss     | 4.86e+10  |
# |    ent_coef        | 1.93      |
# |    ent_coef_loss   | -48       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2190      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 192       |
# |    fps             | 18        |
# |    time_elapsed    | 127       |
# |    total_timesteps | 2347      |
# | train/             |           |
# |    actor_loss      | 6.97e+05  |
# |    critic_loss     | 4.67e+10  |
# |    ent_coef        | 1.95      |
# |    ent_coef_loss   | -49.1     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2240      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 196       |
# |    fps             | 18        |
# |    time_elapsed    | 130       |
# |    total_timesteps | 2395      |
# | train/             |           |
# |    actor_loss      | 6.78e+05  |
# |    critic_loss     | 3.8e+10   |
# |    ent_coef        | 1.98      |
# |    ent_coef_loss   | -50.2     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2290      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 200       |
# |    fps             | 18        |
# |    time_elapsed    | 133       |
# |    total_timesteps | 2443      |
# | train/             |           |
# |    actor_loss      | 6.69e+05  |
# |    critic_loss     | 4.07e+10  |
# |    ent_coef        | 2.01      |
# |    ent_coef_loss   | -51.3     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2340      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 204       |
# |    fps             | 18        |
# |    time_elapsed    | 136       |
# |    total_timesteps | 2491      |
# | train/             |           |
# |    actor_loss      | 6.36e+05  |
# |    critic_loss     | 3.8e+10   |
# |    ent_coef        | 2.04      |
# |    ent_coef_loss   | -52.4     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2390      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 208       |
# |    fps             | 18        |
# |    time_elapsed    | 139       |
# |    total_timesteps | 2539      |
# | train/             |           |
# |    actor_loss      | 6.41e+05  |
# |    critic_loss     | 3.71e+10  |
# |    ent_coef        | 2.07      |
# |    ent_coef_loss   | -53.2     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2430      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 212       |
# |    fps             | 18        |
# |    time_elapsed    | 141       |
# |    total_timesteps | 2587      |
# | train/             |           |
# |    actor_loss      | 6.63e+05  |
# |    critic_loss     | 4.69e+10  |
# |    ent_coef        | 2.1       |
# |    ent_coef_loss   | -54.3     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2480      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 216       |
# |    fps             | 18        |
# |    time_elapsed    | 143       |
# |    total_timesteps | 2635      |
# | train/             |           |
# |    actor_loss      | 6.3e+05   |
# |    critic_loss     | 3.65e+10  |
# |    ent_coef        | 2.13      |
# |    ent_coef_loss   | -55.4     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2530      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 220       |
# |    fps             | 18        |
# |    time_elapsed    | 146       |
# |    total_timesteps | 2683      |
# | train/             |           |
# |    actor_loss      | 5.98e+05  |
# |    critic_loss     | 3.14e+10  |
# |    ent_coef        | 2.16      |
# |    ent_coef_loss   | -56.5     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2580      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 224       |
# |    fps             | 18        |
# |    time_elapsed    | 150       |
# |    total_timesteps | 2731      |
# | train/             |           |
# |    actor_loss      | 6.08e+05  |
# |    critic_loss     | 3.37e+10  |
# |    ent_coef        | 2.2       |
# |    ent_coef_loss   | -57.6     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2630      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 228       |
# |    fps             | 18        |
# |    time_elapsed    | 152       |
# |    total_timesteps | 2779      |
# | train/             |           |
# |    actor_loss      | 5.63e+05  |
# |    critic_loss     | 2.91e+10  |
# |    ent_coef        | 2.22      |
# |    ent_coef_loss   | -58.5     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2670      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 232       |
# |    fps             | 18        |
# |    time_elapsed    | 155       |
# |    total_timesteps | 2827      |
# | train/             |           |
# |    actor_loss      | 5.77e+05  |
# |    critic_loss     | 3.44e+10  |
# |    ent_coef        | 2.26      |
# |    ent_coef_loss   | -59.6     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2720      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 236       |
# |    fps             | 18        |
# |    time_elapsed    | 158       |
# |    total_timesteps | 2875      |
# | train/             |           |
# |    actor_loss      | 5.49e+05  |
# |    critic_loss     | 2.72e+10  |
# |    ent_coef        | 2.29      |
# |    ent_coef_loss   | -60.7     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2770      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 240       |
# |    fps             | 18        |
# |    time_elapsed    | 161       |
# |    total_timesteps | 2923      |
# | train/             |           |
# |    actor_loss      | 5.79e+05  |
# |    critic_loss     | 2.74e+10  |
# |    ent_coef        | 2.33      |
# |    ent_coef_loss   | -61.8     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2820      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 244       |
# |    fps             | 18        |
# |    time_elapsed    | 164       |
# |    total_timesteps | 2971      |
# | train/             |           |
# |    actor_loss      | 5.5e+05   |
# |    critic_loss     | 3.44e+10  |
# |    ent_coef        | 2.36      |
# |    ent_coef_loss   | -62.9     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2870      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 248       |
# |    fps             | 18        |
# |    time_elapsed    | 165       |
# |    total_timesteps | 3019      |
# | train/             |           |
# |    actor_loss      | 5.11e+05  |
# |    critic_loss     | 2.25e+10  |
# |    ent_coef        | 2.39      |
# |    ent_coef_loss   | -63.8     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2910      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 252       |
# |    fps             | 18        |
# |    time_elapsed    | 168       |
# |    total_timesteps | 3067      |
# | train/             |           |
# |    actor_loss      | 5.03e+05  |
# |    critic_loss     | 2.36e+10  |
# |    ent_coef        | 2.43      |
# |    ent_coef_loss   | -64.9     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2960      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 256       |
# |    fps             | 18        |
# |    time_elapsed    | 171       |
# |    total_timesteps | 3115      |
# | train/             |           |
# |    actor_loss      | 5.14e+05  |
# |    critic_loss     | 2.41e+10  |
# |    ent_coef        | 2.46      |
# |    ent_coef_loss   | -66       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3010      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 260       |
# |    fps             | 18        |
# |    time_elapsed    | 174       |
# |    total_timesteps | 3163      |
# | train/             |           |
# |    actor_loss      | 5.54e+05  |
# |    critic_loss     | 3.36e+10  |
# |    ent_coef        | 2.5       |
# |    ent_coef_loss   | -67.1     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3060      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 264       |
# |    fps             | 18        |
# |    time_elapsed    | 177       |
# |    total_timesteps | 3211      |
# | train/             |           |
# |    actor_loss      | 4.93e+05  |
# |    critic_loss     | 2.52e+10  |
# |    ent_coef        | 2.54      |
# |    ent_coef_loss   | -68.2     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3110      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 268       |
# |    fps             | 18        |
# |    time_elapsed    | 179       |
# |    total_timesteps | 3259      |
# | train/             |           |
# |    actor_loss      | 4.82e+05  |
# |    critic_loss     | 1.93e+10  |
# |    ent_coef        | 2.57      |
# |    ent_coef_loss   | -69       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3150      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 272       |
# |    fps             | 18        |
# |    time_elapsed    | 182       |
# |    total_timesteps | 3307      |
# | train/             |           |
# |    actor_loss      | 4.83e+05  |
# |    critic_loss     | 2.3e+10   |
# |    ent_coef        | 2.61      |
# |    ent_coef_loss   | -70.2     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3200      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 276       |
# |    fps             | 18        |
# |    time_elapsed    | 185       |
# |    total_timesteps | 3355      |
# | train/             |           |
# |    actor_loss      | 5.18e+05  |
# |    critic_loss     | 3.52e+10  |
# |    ent_coef        | 2.65      |
# |    ent_coef_loss   | -71.2     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3250      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 280       |
# |    fps             | 18        |
# |    time_elapsed    | 189       |
# |    total_timesteps | 3403      |
# | train/             |           |
# |    actor_loss      | 4.8e+05   |
# |    critic_loss     | 2.32e+10  |
# |    ent_coef        | 2.69      |
# |    ent_coef_loss   | -72.3     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3300      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 284       |
# |    fps             | 17        |
# |    time_elapsed    | 192       |
# |    total_timesteps | 3451      |
# | train/             |           |
# |    actor_loss      | 4.31e+05  |
# |    critic_loss     | 1.57e+10  |
# |    ent_coef        | 2.73      |
# |    ent_coef_loss   | -73.4     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3350      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 288       |
# |    fps             | 17        |
# |    time_elapsed    | 194       |
# |    total_timesteps | 3499      |
# | train/             |           |
# |    actor_loss      | 4.85e+05  |
# |    critic_loss     | 2.68e+10  |
# |    ent_coef        | 2.76      |
# |    ent_coef_loss   | -74.3     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3390      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 292       |
# |    fps             | 17        |
# |    time_elapsed    | 197       |
# |    total_timesteps | 3547      |
# | train/             |           |
# |    actor_loss      | 4.43e+05  |
# |    critic_loss     | 1.61e+10  |
# |    ent_coef        | 2.8       |
# |    ent_coef_loss   | -75.4     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3440      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 296       |
# |    fps             | 17        |
# |    time_elapsed    | 200       |
# |    total_timesteps | 3595      |
# | train/             |           |
# |    actor_loss      | 4.29e+05  |
# |    critic_loss     | 1.9e+10   |
# |    ent_coef        | 2.84      |
# |    ent_coef_loss   | -76.5     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3490      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 300       |
# |    fps             | 17        |
# |    time_elapsed    | 203       |
# |    total_timesteps | 3643      |
# | train/             |           |
# |    actor_loss      | 4.31e+05  |
# |    critic_loss     | 2.21e+10  |
# |    ent_coef        | 2.89      |
# |    ent_coef_loss   | -77.6     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3540      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 304       |
# |    fps             | 17        |
# |    time_elapsed    | 206       |
# |    total_timesteps | 3691      |
# | train/             |           |
# |    actor_loss      | 4.76e+05  |
# |    critic_loss     | 3.09e+10  |
# |    ent_coef        | 2.93      |
# |    ent_coef_loss   | -78.7     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3590      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 308       |
# |    fps             | 17        |
# |    time_elapsed    | 208       |
# |    total_timesteps | 3739      |
# | train/             |           |
# |    actor_loss      | 4.1e+05   |
# |    critic_loss     | 1.67e+10  |
# |    ent_coef        | 2.97      |
# |    ent_coef_loss   | -79.6     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3630      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 312       |
# |    fps             | 17        |
# |    time_elapsed    | 211       |
# |    total_timesteps | 3787      |
# | train/             |           |
# |    actor_loss      | 3.81e+05  |
# |    critic_loss     | 1.26e+10  |
# |    ent_coef        | 3.01      |
# |    ent_coef_loss   | -80.7     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3680      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 316       |
# |    fps             | 17        |
# |    time_elapsed    | 215       |
# |    total_timesteps | 3835      |
# | train/             |           |
# |    actor_loss      | 3.68e+05  |
# |    critic_loss     | 1.4e+10   |
# |    ent_coef        | 3.06      |
# |    ent_coef_loss   | -81.8     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3730      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 320       |
# |    fps             | 17        |
# |    time_elapsed    | 218       |
# |    total_timesteps | 3883      |
# | train/             |           |
# |    actor_loss      | 3.54e+05  |
# |    critic_loss     | 1.12e+10  |
# |    ent_coef        | 3.1       |
# |    ent_coef_loss   | -82.9     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3780      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 324       |
# |    fps             | 17        |
# |    time_elapsed    | 220       |
# |    total_timesteps | 3931      |
# | train/             |           |
# |    actor_loss      | 3.59e+05  |
# |    critic_loss     | 1.22e+10  |
# |    ent_coef        | 3.15      |
# |    ent_coef_loss   | -84       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3830      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# ...
# |    critic_loss     | 3.02e+16  |
# |    ent_coef        | 1.22e+06  |
# |    ent_coef_loss   | -1.03e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 46690     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3900      |
# |    fps             | 16        |
# |    time_elapsed    | 2838      |
# |    total_timesteps | 46843     |
# | train/             |           |
# |    actor_loss      | 6.83e+08  |
# |    critic_loss     | 3.14e+16  |
# |    ent_coef        | 1.24e+06  |
# |    ent_coef_loss   | -1.03e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 46740     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3904      |
# |    fps             | 16        |
# |    time_elapsed    | 2841      |
# |    total_timesteps | 46891     |
# | train/             |           |
# |    actor_loss      | 6.92e+08  |
# |    critic_loss     | 3.21e+16  |
# |    ent_coef        | 1.25e+06  |
# |    ent_coef_loss   | -1.03e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 46790     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3908      |
# |    fps             | 16        |
# |    time_elapsed    | 2844      |
# |    total_timesteps | 46939     |
# | train/             |           |
# |    actor_loss      | 7.02e+08  |
# |    critic_loss     | 3.32e+16  |
# |    ent_coef        | 1.27e+06  |
# |    ent_coef_loss   | -1.03e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 46830     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3912      |
# |    fps             | 16        |
# |    time_elapsed    | 2848      |
# |    total_timesteps | 46987     |
# | train/             |           |
# |    actor_loss      | 7.14e+08  |
# |    critic_loss     | 3.51e+16  |
# |    ent_coef        | 1.29e+06  |
# |    ent_coef_loss   | -1.03e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 46880     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3916      |
# |    fps             | 16        |
# |    time_elapsed    | 2851      |
# |    total_timesteps | 47035     |
# | train/             |           |
# |    actor_loss      | 7.16e+08  |
# |    critic_loss     | 3.62e+16  |
# |    ent_coef        | 1.31e+06  |
# |    ent_coef_loss   | -1.03e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 46930     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3920      |
# |    fps             | 16        |
# |    time_elapsed    | 2854      |
# |    total_timesteps | 47083     |
# | train/             |           |
# |    actor_loss      | 7.33e+08  |
# |    critic_loss     | 3.56e+16  |
# |    ent_coef        | 1.33e+06  |
# |    ent_coef_loss   | -1.03e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 46980     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3924      |
# |    fps             | 16        |
# |    time_elapsed    | 2857      |
# |    total_timesteps | 47131     |
# | train/             |           |
# |    actor_loss      | 7.45e+08  |
# |    critic_loss     | 3.84e+16  |
# |    ent_coef        | 1.35e+06  |
# |    ent_coef_loss   | -1.03e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47030     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3928      |
# |    fps             | 16        |
# |    time_elapsed    | 2860      |
# |    total_timesteps | 47179     |
# | train/             |           |
# |    actor_loss      | 7.52e+08  |
# |    critic_loss     | 3.99e+16  |
# |    ent_coef        | 1.36e+06  |
# |    ent_coef_loss   | -1.03e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47070     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3932      |
# |    fps             | 16        |
# |    time_elapsed    | 2863      |
# |    total_timesteps | 47227     |
# | train/             |           |
# |    actor_loss      | 7.7e+08   |
# |    critic_loss     | 3.9e+16   |
# |    ent_coef        | 1.38e+06  |
# |    ent_coef_loss   | -1.04e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47120     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3936      |
# |    fps             | 16        |
# |    time_elapsed    | 2866      |
# |    total_timesteps | 47275     |
# | train/             |           |
# |    actor_loss      | 7.8e+08   |
# |    critic_loss     | 3.94e+16  |
# |    ent_coef        | 1.41e+06  |
# |    ent_coef_loss   | -1.04e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47170     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3940      |
# |    fps             | 16        |
# |    time_elapsed    | 2869      |
# |    total_timesteps | 47323     |
# | train/             |           |
# |    actor_loss      | 7.88e+08  |
# |    critic_loss     | 4.01e+16  |
# |    ent_coef        | 1.43e+06  |
# |    ent_coef_loss   | -1.04e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47220     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3944      |
# |    fps             | 16        |
# |    time_elapsed    | 2872      |
# |    total_timesteps | 47371     |
# | train/             |           |
# |    actor_loss      | 8.04e+08  |
# |    critic_loss     | 4.36e+16  |
# |    ent_coef        | 1.45e+06  |
# |    ent_coef_loss   | -1.04e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47270     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3948      |
# |    fps             | 16        |
# |    time_elapsed    | 2875      |
# |    total_timesteps | 47419     |
# | train/             |           |
# |    actor_loss      | 8.1e+08   |
# |    critic_loss     | 4.61e+16  |
# |    ent_coef        | 1.47e+06  |
# |    ent_coef_loss   | -1.04e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47310     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3952      |
# |    fps             | 16        |
# |    time_elapsed    | 2878      |
# |    total_timesteps | 47467     |
# | train/             |           |
# |    actor_loss      | 8.23e+08  |
# |    critic_loss     | 4.67e+16  |
# |    ent_coef        | 1.49e+06  |
# |    ent_coef_loss   | -1.04e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47360     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3956      |
# |    fps             | 16        |
# |    time_elapsed    | 2882      |
# |    total_timesteps | 47515     |
# | train/             |           |
# |    actor_loss      | 8.36e+08  |
# |    critic_loss     | 4.69e+16  |
# |    ent_coef        | 1.51e+06  |
# |    ent_coef_loss   | -1.04e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47410     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3960      |
# |    fps             | 16        |
# |    time_elapsed    | 2885      |
# |    total_timesteps | 47563     |
# | train/             |           |
# |    actor_loss      | 8.48e+08  |
# |    critic_loss     | 4.94e+16  |
# |    ent_coef        | 1.53e+06  |
# |    ent_coef_loss   | -1.04e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47460     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3964      |
# |    fps             | 16        |
# |    time_elapsed    | 2889      |
# |    total_timesteps | 47611     |
# | train/             |           |
# |    actor_loss      | 8.62e+08  |
# |    critic_loss     | 4.92e+16  |
# |    ent_coef        | 1.56e+06  |
# |    ent_coef_loss   | -1.04e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47510     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3968      |
# |    fps             | 16        |
# |    time_elapsed    | 2892      |
# |    total_timesteps | 47659     |
# | train/             |           |
# |    actor_loss      | 8.77e+08  |
# |    critic_loss     | 4.58e+16  |
# |    ent_coef        | 1.58e+06  |
# |    ent_coef_loss   | -1.04e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47550     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3972      |
# |    fps             | 16        |
# |    time_elapsed    | 2895      |
# |    total_timesteps | 47707     |
# | train/             |           |
# |    actor_loss      | 8.81e+08  |
# |    critic_loss     | 5.44e+16  |
# |    ent_coef        | 1.6e+06   |
# |    ent_coef_loss   | -1.05e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47600     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 12        |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 3976      |
# |    fps             | 16        |
# |    time_elapsed    | 2899      |
# |    total_timesteps | 47755     |
# | train/             |           |
# |    actor_loss      | 9.05e+08  |
# |    critic_loss     | 5.57e+16  |
# |    ent_coef        | 1.62e+06  |
# |    ent_coef_loss   | -1.05e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47650     |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 11
#       2 checkpoint_callback = CheckpointCallback(
#       3     save_freq=50000,  # Save model every 50,000 steps
#       4     save_path="./checkpoints/",
#    (...)
#       7     save_vecnormalize=True,
#       8 )
#      10 # Train the agent for 1 million timesteps (longer training for better results)
# ---> 11 model.learn(total_timesteps=100_000, callback=checkpoint_callback)
#      13 # Save final model
#      14 model.save("sac_spacecraft_final")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\sac\sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\sac\sac.py:267, in SAC.train(self, gradient_steps, batch_size)
#     265 # Optimize the critic
#     266 self.critic.optimizer.zero_grad()
# --> 267 critic_loss.backward()
#     268 self.critic.optimizer.step()
#     270 # Compute actor loss
#     271 # Alternative: actor_loss = th.mean(log_prob - qf1_pi)
#     272 # Min over all critic networks
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\autograd\graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# Load trained model [if fully finished]
model = SAC.load("sac_spacecraft_final")

# %%
# Load last checkpoint
model = SAC.load("checkpoints/sac_spacecraft_50000_steps.zip")

# %%
obs, _ = gym_env.reset()
done = False

while not done:
    action, _ = model.predict(obs, deterministic=True)  # Use deterministic actions for evaluation
    obs, reward, done, _, _ = gym_env.step(action)
    print(f"Reward: {reward}")

print("Evaluation complete.")
# Out:
# Reward: -108.5066099634368
# Reward: -109.3109497601294
# Reward: -110.14604156855623
# Reward: -110.99364056511632
# Reward: -111.84747458822928
# Reward: -112.70484861632626
# Reward: -113.56442067474606
# Reward: -114.42544942386017
# Reward: -115.28749258393411
# Reward: -116.15027018663285
# Reward: -117.0135964734116
# Reward: -217.87734338829438
# Evaluation complete.

# %% [markdown]
# RUN_01:
# Reward: -107.76274152837807
# Reward: -108.56436027711736
# Reward: -109.39830038893808
# Reward: -110.24529011169618
# Reward: -111.09875427400894
# Reward: -111.95588236623631
# Reward: -112.8152800644034
# Reward: -113.67617920864811
# Reward: -114.53812247680536
# Reward: -115.40082085733859
# Reward: -116.26408284858648
# Reward: -217.12777658172516
# Evaluation complete.
